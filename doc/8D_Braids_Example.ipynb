# %%
from pychomp import *
from pychomp.Braids import *

# %%
braid_diagram = BraidDiagram([[1,4,3,3,1,4,3,3,1], [2,1,2,1,2,1,2,1,2],
                              [3,3,1,4,3,3,1,4,3], [4,2,4,2,4,2,4,2,4]])

# %%
braid_diagram
# Out:
# Braid Diagram

# %%
# %%time
braid_complex, braid_graph = BraidComplex(braid_diagram)
# Out:
# CPU times: user 55.3 s, sys: 1.3 s, total: 56.6 s
# Wall time: 57.5 s

# %%
# %%time
(poset, graded_complex) = FlowGradedComplex(braid_complex, braid_graph)
# Out:
# CPU times: user 29.7 s, sys: 946 ms, total: 30.7 s
# Wall time: 31.1 s

# %%
# %%time
connection_matrix = ConnectionMatrix(graded_complex)
# Out:
# CPU times: user 12min 37s, sys: 4.89 s, total: 12min 42s
# Wall time: 12min 43s

# %%
# %%time
reduced_poset = Poset(InducedSubgraph(TransitiveClosure(poset), lambda v : v in connection_matrix.count()))
# Out:
# CPU times: user 1.93 s, sys: 63.9 ms, total: 1.99 s
# Wall time: 2 s

# %%
# %%time
df = DrawGradedComplex(connection_matrix, reduced_poset)
# Out:
# CPU times: user 802 µs, sys: 11 µs, total: 813 µs
# Wall time: 820 µs

# %%
with open('cm.gv','w') as outfile:
    outfile.write(df.graphviz())

# %%
graphviz.Source(df.graphviz())
# df

# %%
bd = lambda cell : connection_matrix.complex().boundary(cell)
C = connection_matrix.complex()
print("Connection Matrix Data")
print("======================")
for d in range(0,C.dimension()):
    print("  Boundaries of " + str(d) + "-cells in Connection Fibration:")
    for c in C(d):
        print("    " + str( c) + ' : ' + str(bd({c})))
# Out:
# Connection Matrix Data
# ======================
#   Boundaries of 0-cells in Connection Fibration:
#     0 : set()
#     1 : set()
#   Boundaries of 1-cells in Connection Fibration:
#     2 : {0, 1}
#     3 : {0, 1}
#     4 : {0, 1}
#     5 : {0, 1}
#     6 : {0, 1}
#   Boundaries of 2-cells in Connection Fibration:
#     7 : {2, 5}
#     8 : {2, 3}
#     9 : {2, 3}
#     10 : {3, 5}
#     11 : {4, 5}
#     12 : {2, 4}
#     13 : {3, 4}
#     14 : {3, 4}
#     15 : {2, 6}
#     16 : {2, 6}
#     17 : {3, 6}
#     18 : {4, 6}
#     19 : {5, 6}
#     20 : set()
#     21 : {4, 6}
#   Boundaries of 3-cells in Connection Fibration:
#     22 : {9, 10, 20, 7}
#     23 : {8, 10, 20, 7}
#     24 : {8, 9}
#     25 : {19, 7, 15}
#     26 : {10, 11, 13}
#     27 : {11, 18, 19}
#     28 : {9, 12, 13}
#     29 : {8, 12, 13}
#     30 : {11, 12, 7}
#     31 : {9, 12, 14}
#     32 : {13, 14}
#     33 : {11, 12, 20, 7}
#     34 : {16, 12, 21}
#     35 : {17, 21, 13}
#     36 : {10, 11, 14}
#     37 : {19, 11, 21}
#     38 : {16, 19, 7}
#     39 : {16, 15}
#     40 : {17, 10, 19}
#     41 : {17, 9, 15}
#     42 : {16, 9, 17}
#     43 : {16, 17, 8}
#     44 : {17, 18, 14}
#     45 : {18, 12, 15}
#     46 : {16, 18, 12}
#     47 : {17, 18, 13}
#     48 : {17, 10, 19, 20}
#     49 : {18, 21}
#   Boundaries of 4-cells in Connection Fibration:
#     50 : {48, 33, 40, 30}
#     51 : {36, 40, 41, 25, 30, 31}
#     52 : {24, 32, 29, 31}
#     53 : {25, 27, 45, 30}
#     54 : {41, 28, 45, 47}
#     55 : {24, 28, 29}
#     56 : {41, 44, 45, 31}
#     57 : {38, 34, 37, 30}
#     58 : {33, 26, 29, 23}
#     59 : {32, 28, 31}
#     60 : {24, 22, 23}
#     61 : {48, 33, 40, 30}
#     62 : {33, 26, 28, 22}
#     63 : {34, 35, 28, 42}
#     64 : {33, 36, 22, 31}
#     65 : {32, 26, 36}
#     66 : {32, 49, 35, 44}
#     67 : {41, 42, 39}
#     68 : {24, 41, 43, 39}
#     69 : {24, 42, 43}
#     70 : {25, 38, 39}
#     71 : {48, 43, 38, 23}
#     72 : {48, 25, 22, 41}
#     73 : {38, 42, 48, 22}
#     74 : {40, 27, 44, 36}
#     75 : {38, 27, 46, 30}
#     76 : {45, 46, 39}
#     77 : {43, 29, 46, 47}
#     78 : {40, 26, 27, 47}
#     79 : {42, 28, 46, 47}
#     80 : {42, 44, 46, 31}
#     81 : {32, 44, 47}
#     82 : {49, 34, 45, 39}
#     83 : {33, 34, 37, 40, 43, 23}
#     84 : {43, 34, 35, 29}
#     85 : {40, 26, 35, 37}
#     86 : {33, 36, 44, 45, 48, 25}
#     87 : {35, 37, 48, 23, 29, 30}
#     88 : {49, 27, 37}
#     89 : {49, 34, 46}
#     90 : {49, 35, 47}
#   Boundaries of 5-cells in Connection Fibration:
#     91 : {56, 74, 51, 53}
#     92 : {64, 65, 52, 58, 60}
#     93 : {65, 78, 51, 53, 54, 59}
#     94 : {64, 65, 59, 62}
#     95 : {56, 81, 59, 54}
#     96 : {59, 52, 55}
#     97 : {68, 70, 71, 72, 60}
#     98 : {72, 64, 50, 51}
#     99 : {56, 72, 64, 86}
#     100 : {65, 72, 81, 86, 54, 62}
#     101 : {67, 82, 54, 90, 63}
#     102 : {58, 60, 62, 55}
#     103 : {69, 84, 63, 55}
#     104 : {70, 82, 53, 88, 57}
#     105 : {57, 84, 87, 71}
#     106 : {65, 66, 74, 85, 88}
#     107 : {67, 70, 74, 75, 80, 51}
#     108 : {69, 83, 85, 60, 62, 63}
#     109 : {67, 68, 69}
#     110 : {72, 73, 67, 70}
#     111 : {80, 56, 67, 76}
#     112 : {69, 77, 80, 81, 52}
#     113 : {67, 76, 54, 79}
#     114 : {68, 76, 77, 54, 55}
#     115 : {69, 77, 79, 55}
#     116 : {75, 76, 53, 70}
#     117 : {74, 50, 53, 86}
#     118 : {71, 75, 77, 87, 88, 90}
#     119 : {65, 81, 74, 78}
#     120 : {80, 81, 59, 79}
#     121 : {57, 83, 61, 71}
#     122 : {58, 83, 84, 85}
#     123 : {58, 85, 61, 87}
#     124 : {73, 60, 69, 71}
#     125 : {73, 87, 55, 57, 60, 63}
#     126 : {89, 82, 76}
#     127 : {77, 78, 83, 88, 89, 58}
#     128 : {89, 90, 84, 77}
#     129 : {88, 90, 85, 78}
#     130 : {89, 90, 63, 79}
#     131 : {89, 57, 75, 88}
#     132 : {64, 70, 73, 76, 80, 86}
#     133 : {66, 80, 89, 59, 63}
#     134 : {81, 66, 90}
#   Boundaries of 6-cells in Connection Fibration:
#     135 : {91, 119, 93, 95}
#     136 : {102, 108, 121, 123, 124, 125}
#     137 : {97, 101, 104, 110, 114, 116, 118, 125}
#     138 : {98, 100, 117, 119, 93, 94}
#     139 : {99, 100, 94, 95}
#     140 : {133, 101, 134, 111, 126, 95}
#     141 : {96, 94, 92, 102}
#     142 : {105, 124, 125, 103}
#     143 : {96, 128, 133, 134, 103, 112}
#     144 : {113, 114, 115, 109}
#     145 : {107, 91, 116, 111}
#     146 : {96, 109, 111, 112, 114, 95}
#     147 : {107, 113, 116, 119, 120, 93}
#     148 : {120, 113, 111, 95}
#     149 : {133, 106, 108, 112, 119, 92, 94, 127}
#     150 : {96, 115, 112, 120}
#     151 : {97, 124, 109, 110}
#     152 : {129, 131, 133, 101, 104, 106, 107, 93}
#     153 : {122, 108, 102, 103}
#     154 : {99, 132, 110, 111}
#     155 : {121, 122, 123, 105}
#     156 : {129, 131, 118, 121, 123, 127}
#     157 : {104, 131, 116, 126}
#     158 : {128, 129, 122, 127}
#     159 : {128, 101, 103, 109, 114, 126}
#     160 : {129, 130, 102, 108, 115, 127}
#     161 : {113, 130, 101, 126}
#     162 : {128, 130, 115, 103}
#     163 : {98, 132, 107, 110, 116, 117}
#     164 : {99, 98, 91, 117}
#     165 : {97, 132, 100, 102, 112, 124, 114, 92}
#     166 : {128, 105, 131, 118}
#     167 : {132, 100, 110, 113, 120, 94}
#     168 : {130, 131, 115, 118, 124, 125}
#     169 : {120, 130, 133, 134}
#     170 : {129, 106, 134, 119}
#   Boundaries of 7-cells in Connection Fibration:
#     171 : {138, 139, 164, 135}
#     172 : {136, 153, 155, 142}
#     173 : {170, 141, 143, 149, 153, 158}
#     174 : {165, 167, 141, 144, 150, 151}
#     175 : {161, 168, 137, 144, 151, 157}
#     176 : {145, 147, 148, 135}
#     177 : {160, 169, 170, 141, 149, 150}
#     178 : {144, 146, 148, 150}
#     179 : {135, 170, 140, 145, 152, 157}
#     180 : {160, 153, 162, 158}
#     181 : {144, 161, 162, 159}
#     182 : {145, 154, 163, 164}
#     183 : {165, 139, 141, 146, 151, 154}
#     184 : {154, 139, 148, 167}
#     185 : {169, 148, 161, 140}
#     186 : {158, 155, 156, 166}
#     187 : {166, 137, 142, 151, 157, 159}
#     188 : {168, 162, 166, 142}
#     189 : {161, 169, 170, 147, 152, 157}
#     190 : {169, 162, 150, 143}

# %%
braid_complex.size()
# Out:
# 429981696
